# %%
from surprise import Dataset
from surprise import Reader
import pandas as pd
from surprise.model_selection import GridSearchCV
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import SVD, SVDpp, NMF


reader = Reader(line_format='user item rating timestamp', sep='\t')
data = Dataset.load_from_file('ml-100k/u1.base', reader=reader)
pd.DataFrame(data.__dict__['raw_ratings'], columns=['user_id','movie_id','rating','timestamp'])
# Out:
#       user_id movie_id  rating  timestamp
# 0           1        1     5.0  874965758
# 1           1        2     3.0  876893171
# 2           1        3     4.0  878542960
# 3           1        4     3.0  876893119
# 4           1        5     3.0  889751712
# ...       ...      ...     ...        ...
# 79995     943     1067     2.0  875501756
# 79996     943     1074     4.0  888640250
# 79997     943     1188     3.0  888640250
# 79998     943     1228     3.0  888640275
# 79999     943     1330     3.0  888692465
#
# [80000 rows x 4 columns]

# %%
model = SVD()

for i in range(2,10):
    cross_validate(model, data, measures=['rmse', 'mae'], cv=i, verbose=True)
    print()
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 2 split(s).
#
#                   Fold 1  Fold 2  Mean    Std
# RMSE (testset)    0.9632  0.9568  0.9600  0.0032
# MAE (testset)     0.7621  0.7569  0.7595  0.0026
# Fit time          0.51    0.46    0.48    0.03
# Test time         0.33    0.45    0.39    0.06
#
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9515  0.9483  0.9509  0.9502  0.0014
# MAE (testset)     0.7536  0.7482  0.7524  0.7514  0.0023
# Fit time          0.68    0.64    0.67    0.66    0.01
# Test time         0.17    0.18    0.44    0.26    0.12
#
# Evaluating RMSE, MAE of algorithm SVD on 4 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Mean    Std
# RMSE (testset)    0.9486  0.9504  0.9431  0.9473  0.9474  0.0027
# MAE (testset)     0.7487  0.7527  0.7425  0.7514  0.7488  0.0040
# Fit time          0.71    0.73    0.78    0.67    0.72    0.04
# ...

# %%
param_grid = {'n_epochs': [6, 11], 'lr_all': [0.004, 0.01],
              'reg_all': [0.4, 0.6]}

gridsearch = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=7)

gridsearch.fit(data)

print(gridsearch.best_score['rmse'])

print(gridsearch.best_params['rmse'])
# Out:
# 0.9562053984416112
# {'n_epochs': 11, 'lr_all': 0.01, 'reg_all': 0.4}

# %%
model = SVDpp()

for i in range(2,10):
    cross_validate(model, data, measures=['rmse', 'mae'], cv=i, verbose=True)
    print()
# Out:
# Evaluating RMSE, MAE of algorithm SVDpp on 2 split(s).
#
#                   Fold 1  Fold 2  Mean    Std
# RMSE (testset)    0.9424  0.9482  0.9453  0.0029
# MAE (testset)     0.7434  0.7464  0.7449  0.0015
# Fit time          7.36    7.23    7.29    0.06
# Test time         3.82    4.35    4.08    0.27
#
# Evaluating RMSE, MAE of algorithm SVDpp on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9385  0.9389  0.9350  0.9375  0.0017
# MAE (testset)     0.7381  0.7380  0.7352  0.7371  0.0014
# Fit time          13.32   12.98   13.34   13.21   0.17
# Test time         3.55    3.55    3.70    3.60    0.07
#
# Evaluating RMSE, MAE of algorithm SVDpp on 4 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Mean    Std
# RMSE (testset)    0.9196  0.9296  0.9429  0.9255  0.9294  0.0086
# MAE (testset)     0.7239  0.7300  0.7437  0.7258  0.7308  0.0077
# Fit time          16.42   15.80   16.43   16.71   16.34   0.33
# ...

# %%
param_grid = {'n_epochs': [6, 11], 'lr_all': [0.004, 0.01],
              'reg_all': [0.4, 0.6]}

gridsearch = GridSearchCV(SVDpp, param_grid, measures=['rmse', 'mae'], cv=7)

gridsearch.fit(data)

print(gridsearch.best_score['rmse'])

print(gridsearch.best_params['rmse'])
# Out:
# 0.9564847147861899
# {'n_epochs': 11, 'lr_all': 0.01, 'reg_all': 0.4}

# %%
model = NMF()

for i in range(2,10):
    cross_validate(model, data, measures=['rmse', 'mae'], cv=i, verbose=True)
    print()
# Out:
# Evaluating RMSE, MAE of algorithm NMF on 2 split(s).
#
#                   Fold 1  Fold 2  Mean    Std
# RMSE (testset)    1.0176  1.0096  1.0136  0.0040
# MAE (testset)     0.7974  0.7934  0.7954  0.0020
# Fit time          0.91    0.82    0.87    0.05
# Test time         0.27    0.74    0.50    0.24
#
# Evaluating RMSE, MAE of algorithm NMF on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9827  0.9804  0.9962  0.9864  0.0069
# MAE (testset)     0.7734  0.7706  0.7800  0.7747  0.0039
# Fit time          0.95    1.01    1.00    0.99    0.03
# Test time         0.15    0.17    0.16    0.16    0.01
#
# Evaluating RMSE, MAE of algorithm NMF on 4 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Mean    Std
# RMSE (testset)    0.9820  0.9766  0.9849  0.9753  0.9797  0.0039
# MAE (testset)     0.7698  0.7655  0.7748  0.7653  0.7688  0.0039
# Fit time          1.16    1.18    1.17    1.14    1.16    0.02
# ...
